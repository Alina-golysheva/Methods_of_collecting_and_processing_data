# %% [markdown]
# Это была работа над ошибками:
# Вес еды - использован метод find_all. Здесь можно и обычным find найти - вернется сразу тег, а не список. И да, кстати из тега выдергиваем значение текста, чтобы сразу были чистые данные:
#
# eda_weight = eda.find('span',{'class':'RestaurantStorePageMenuItem_weight'}).getText() С ценой - та же ситуация - забыли getText()
#
# eda_price = eda.find('span',{'class':'RestaurantStorePageMenuItem_price'}).getText() Раз уж работем с ценой. То в идеале из полученных данных извлечь саму цифру и преобразовать к int - потом очень сильно пригодится. Кстати также с весом - там вообще можно разбить на две составляющие на саму фийру и на ед. измерения. - тоже будет полезно.
#
# Попрошу вас доделать именно до такого состояния. Поля которые должны присутствовать: Имя, вес (число int), единицы измерения, цена(число int или float) и в идеале еще добавить магазин откуда собраны данные. Мы с жтим наором будем работать в следующем ДЗ, поэтому пригодится) Пока оценка "хорошо"

# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import pandas as pd

# %%
main_link = 'https://eda.yandex/shop/azbuka_vkusa_simferopolskij_bulvar_22k3?category=782350'
response = requests.get(main_link).text
soup = bs(response,'lxml')

eda_block = soup.find('div',{'class':'RestaurantPageStorePageCategoryListWithItems_root'})
eda_list = eda_block.find_all('div',{'class':'RestaurantStorePageMenuCategory_itemWrapper'})

bakalea = []
for eda in eda_list:
    eda_data = {}
    eda_name = eda.find('h3').getText()
    eda_weight = eda.find('span',{'class':'RestaurantStorePageMenuItem_weight'}).getText()
    eda_price =  eda.find('span',{'class':'RestaurantStorePageMenuItem_price'})
  
    if not eda_price:
        eda_price = 0
        eda_curr = None
    else:
        eda_price = eda_price.getText()
        eda_curr = eda_price[-1]
        eda_price = eda_price.replace(' ₽', '')
        
    eda_data['name'] = eda_name
    eda_data['weight'] = eda_weight      
    eda_data['price'] = int(eda_price)
    eda_data['currency'] = eda_curr
    bakalea.append(eda_data)

# %% [markdown]
# 3 урок
# 1) Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД (без датафрейма)
#
# 2) Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы. Поиск по двум полям (мин и макс зарплату)
#
# 3) Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта

# %%
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)
db = client['eda']
collection = db['col']
for i in bakalea:
    try:
        db.collection.insert_one(i)
    except:
        pass
for  db.collection in  db.collection.find({'price':{'$gt':500}}):
     pprint( db.collection)
# Out:
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90ac'),
#  'currency': '₽',
#  'name': 'Рис «Акватика» дикий, «Мистраль»',
#  'price': 724,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90c3'),
#  'currency': '₽',
#  'name': 'Рис басмати Elonga длиннозерный, Dunar, 1 кг',
#  'price': 586,
#  'weight': '1000 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90ca'),
#  'currency': '₽',
#  'name': 'Рис черный Био odri rice',
#  'price': 580,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90d7'),
#  'currency': '₽',
#  'name': 'Рис «Арборио» Био, Alce Nero',
#  'price': 558,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90d8'),
#  'currency': '₽',
#  'name': 'Рис Baldo коричневый нешлифованный Био, Alce Nero',
#  'price': 521,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90d9'),
#  'currency': '₽',
#  'name': 'Рис Dunar Басмати Elonga Sela пропаренный длиннозерный 1 кг банка',
#  'price': 539,
#  'weight': '1000 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90e2'),
#  'currency': '₽',
#  'name': 'Рис Ermes коричневый, Riso Scotti',
#  'price': 521,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90f3'),
#  'currency': '₽',
#  'name': 'Рис "Карнароли" с черным трюфелем Giuliano Tartufi',
#  'price': 757,
#  'weight': '350 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea90f6'),
#  'currency': '₽',
#  'name': 'Крупа «Смесь булгура и киноа», Tipiak',
#  'price': 670,
#  'weight': '400 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea9110'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Luciana Mosconi Гарганелли яичные пакет',
#  'price': 658,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea9113'),
#  'currency': '₽',
#  'name': 'Макаронные изделия "Спагеттино" Sapori di Napoli',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea9114'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Sapori di Napoli Ригатоне Sapori di Napoli s.r.l. '
#          'пакет',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea914a'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Лумакине и Гобетти Sapori di Napoli',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea914b'),
#  'currency': '₽',
#  'name': 'Макаронные изделия яичные «Тальятелле с белым трюфелем», Giuliano '
#          'Tartufi',
#  'price': 675,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea914c'),
#  'currency': '₽',
#  'name': 'Макаронные изделия яичные Талиолини Sapori di Napoli',
#  'price': 510,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea914d'),
#  'currency': '₽',
#  'name': 'Макаронные изделия яичные «Паппарделле», Sapori di Napoli',
#  'price': 510,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea9164'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Giuliano Tartufi Странгоцци с черным трюфелем '
#          'Giuliano Tartufi srl',
#  'price': 762,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea916b'),
#  'currency': '₽',
#  'name': 'Макаронные изделия спагетто классико, Sapori di Napoli',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea916c'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Sapori di Napoli Спагетто Китарра Pastificio '
#          'Artigionale Romita Srl пакет',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe6b5ed4be4a63f6ea916d'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Sapori di Napoli Фузилло Сичилиано Pastificio '
#          'Artigionale Romita Srl пакет',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff5585d4'),
#  'currency': '₽',
#  'name': 'Рис «Акватика» дикий, «Мистраль»',
#  'price': 724,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff5585eb'),
#  'currency': '₽',
#  'name': 'Рис басмати Elonga длиннозерный, Dunar, 1 кг',
#  'price': 586,
#  'weight': '1000 г'}
# {'_id': ObjectId('5efe761ec9152935ff5585f2'),
#  'currency': '₽',
#  'name': 'Рис черный Био odri rice',
#  'price': 580,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff5585ff'),
#  'currency': '₽',
#  'name': 'Рис «Арборио» Био, Alce Nero',
#  'price': 558,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff558600'),
#  'currency': '₽',
#  'name': 'Рис Baldo коричневый нешлифованный Био, Alce Nero',
#  'price': 521,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff558601'),
#  'currency': '₽',
#  'name': 'Рис Dunar Басмати Elonga Sela пропаренный длиннозерный 1 кг банка',
#  'price': 539,
#  'weight': '1000 г'}
# {'_id': ObjectId('5efe761ec9152935ff55860a'),
#  'currency': '₽',
#  'name': 'Рис Ermes коричневый, Riso Scotti',
#  'price': 521,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff55861b'),
#  'currency': '₽',
#  'name': 'Рис "Карнароли" с черным трюфелем Giuliano Tartufi',
#  'price': 757,
#  'weight': '350 г'}
# {'_id': ObjectId('5efe761ec9152935ff55861e'),
#  'currency': '₽',
#  'name': 'Крупа «Смесь булгура и киноа», Tipiak',
#  'price': 670,
#  'weight': '400 г'}
# {'_id': ObjectId('5efe761ec9152935ff558638'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Luciana Mosconi Гарганелли яичные пакет',
#  'price': 658,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff55863b'),
#  'currency': '₽',
#  'name': 'Макаронные изделия "Спагеттино" Sapori di Napoli',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff55863c'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Sapori di Napoli Ригатоне Sapori di Napoli s.r.l. '
#          'пакет',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff558672'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Лумакине и Гобетти Sapori di Napoli',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff558673'),
#  'currency': '₽',
#  'name': 'Макаронные изделия яичные «Тальятелле с белым трюфелем», Giuliano '
#          'Tartufi',
#  'price': 675,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe761ec9152935ff558674'),
#  'currency': '₽',
#  'name': 'Макаронные изделия яичные Талиолини Sapori di Napoli',
#  'price': 510,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe761ec9152935ff558675'),
#  'currency': '₽',
#  'name': 'Макаронные изделия яичные «Паппарделле», Sapori di Napoli',
#  'price': 510,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe761ec9152935ff55868c'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Giuliano Tartufi Странгоцци с черным трюфелем '
#          'Giuliano Tartufi srl',
#  'price': 762,
#  'weight': '250 г'}
# {'_id': ObjectId('5efe761ec9152935ff558693'),
#  'currency': '₽',
#  'name': 'Макаронные изделия спагетто классико, Sapori di Napoli',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff558694'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Sapori di Napoli Спагетто Китарра Pastificio '
#          'Artigionale Romita Srl пакет',
#  'price': 510,
#  'weight': '500 г'}
# {'_id': ObjectId('5efe761ec9152935ff558695'),
#  'currency': '₽',
#  'name': 'Макаронные изделия Sapori di Napoli Фузилло Сичилиано Pastificio '
#          'Artigionale Romita Srl пакет',
#  'price': 510,
#  'weight': '500 г'}
